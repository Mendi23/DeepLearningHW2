# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bb}[1]{\boldsymbol{#1}}
# $$
# # Part 2: Optimization and Training
# <a id=part2></a>

# %% [markdown]
# In this part we will learn how to implement optimization algorithms for deep networks. Additionally, we'll learn how to write training loops and implement a modular model trainer.
# We'll use our optimizers and training code to test a few configurations for classifying images with an MLP model.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import unittest
import torch
import torchvision
import torchvision.transforms as tvtf

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

seed = 42

plt.rcParams.update({'font.size': 12})
test = unittest.TestCase()

# %% [markdown]
# ## Implementing Optimization Algorithms
# <a id=part2_1></a>

# %% [markdown]
# In the context of deep learning, an optimization algorithm is some method of iteratively updating model parameters so that the loss converges toward some local minimum (which we hope will be good enough).
#
# Gradient descent-based methods are by far the most popular algorithms for optimization of neural network parameters.
# However the high-dimensional loss-surfaces we encounter in deep learning applications are highly non-convex.
# They may be riddled with local minima, saddle points, large plateaus and a host of very challenging "terrain" for gradient-based optimization.
# This gave rise to many different methods of performing the parameter updates based on the loss gradients,
# aiming to tackle these optimization challenges.
#
# The most basic gradient-based update rule can be written as,
#
# $$
# \vec{\theta} \leftarrow \vec{\theta} - \eta \nabla_{\vec{\theta}} L(\vec{\theta}; \mathcal{D})
# $$
#
# where $\mathcal{D} = \left\{ (\vec{x}^i, \vec{y}^i) \right\}_{i=1}^{M}$ is our training dataset or part of it. Specifically, if we have in total $N$ training samples, then
# - If $M=N$ this is known as regular gradient descent. If the dataset does not fit in memory it becomes infeasible to compute.
# - If $M=1$, the loss is computed w.r.t. a single different sample each time. This is known as stochastic gradient descent.
# - If $1<M<N$ this is known as stochastic mini-batch gradient descent. This is the most commonly-used option.
#
# The intuition behind gradient descent is simple: since the gradient of a multivariate function points to the direction of steepest ascent ("uphill"), we move in the opposite direction. A small step size $\eta$ known as the **learning rate** is required since, as with any derivative, the gradient's value is only accurate close to the point it was evaluated at (the current value of $\vec{\theta}$).
#
# <img src="imgs/sgd2d.png" width="600" />
#
# The idea behind the stochastic versions is that by constantly changing the samples we compute the loss with,
# we get a dynamic error surface, i.e. it's different for each set of training samples.
# This is thought to generally improve the optimization since it may help the optimizer get out of flat regions or sharp local minima since these features may disappear in the loss surface of subsequent batches. The image below illustrates this. The different lines are different 1-dimensional losses for different training set-samples.
#
# <img src="imgs/sgd1d.png" width="600" />

# %% [markdown]
# All deep learning frameworks provide implementations of various gradient-based optimization algorithms.
# Here we'll implement our own optimization module from scratch, this time keeping a similar API to the PyTorch `optim` package.
#
# We define a base `Optimizer` class. An optimizer holds a set of parameter tensors (these are the trainable parameters of some model) and maintains internal state. It may be used as follows:
# - After the forward pass has been performed the optimizer's `zero_grad()` function is invoked to clear the parameter gradients computed by previous iterations.
# - After the backward pass has been performed, and gradients have been calculated for these parameters, the optimizer's `step()` function is invoked in order to update the value of each parameter based on it's gradient.
#
# The exact method of update is implementation-specific for each optimizer and may depend on it's internal state. In addition, adding the regularization penalty to the gradient is handled by the optimizer since it only depends on the parameter values (and not the data).

# %%
import hw2.optimizers as optimizers
help(optimizers.Optimizer)
# Out:
# Help on class Optimizer in module hw2.optimizers:
#
# class Optimizer(abc.ABC)
#  |  Optimizer(params)
#  |
#  |  Base class for optimizers.
#  |
#  |  Method resolution order:
#  |      Optimizer
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, params)
#  |      :param params: A sequence of model parameters to optimize. Can be a
#  |      list of (param,grad) tuples as returned by the Blocks, or a list of
#  |      pytorch tensors in which case the grad will be taken from them.
#  |
#  |  step(self)
#  |      Updates all the registered parameter values based on their gradients.
#  |
#  |  zero_grad(self)
#  |      Sets the gradient of the optimized parameters to zero (in place).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  params
#  |      :return: A sequence of parameter tuples, each tuple containing
#  |      (param_data, param_grad). The data should be updated in-place
#  |      according to the grad.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset({'step'})

# %% [markdown]
# ## Vanilla SGD with Regularization
# <a id=part2_2></a>

# %% [markdown]
# Let's start by implementing the simplest gradient based optimizer. The update rule will be exacly as stated above, but we'll also add a L2-regularization term to the gradient. Remember that in the **loss function**, the L2 regularization term is expressed by
#
# $$R(\vec{\theta}) = \frac{1}{2}\lambda||\vec{\theta}||^2_2.$$

# %% [markdown]
# **TODO**: Complete the implementation of the `VanillaSGD` class in the `hw2/optimizers.py` module.

# %%
# Test VanillaSGD
torch.manual_seed(42)
p = torch.randn(500, 10)
dp = torch.randn(*p.shape)*2
params = [(p, dp)]

vsgd = optimizers.VanillaSGD(params, learn_rate=0.5, reg=0.1)
vsgd.step()

expected_p = torch.load('tests/assets/expected_vsgd.pt')
diff = torch.norm(p-expected_p).item()
test.assertLess(diff, 1e-3)

# %% [markdown]
# ## Training
# <a id=part2_3></a>

# %% [markdown]
# Now that we can build a model and loss function, compute their gradients and we have an optimizer, we can finally do some training!
#
# In the spirit of more modular software design, we'll implement a class that will aid us in automating the repetitive training loop code that we usually write over and over again. This will be useful for both training our `Block`-based models and also later for training PyTorch `nn.Module`s.
#
# Here's our `Trainer` API:

# %%
import hw2.training as training
help(training.Trainer)
# Out:
# Help on class Trainer in module hw2.training:
#
# class Trainer(abc.ABC)
#  |  Trainer(model, loss_fn, optimizer, device=None)
#  |
#  |  A class abstracting the various tasks of training models.
#  |
#  |  Provides methods at multiple levels of granularity:
#  |  - Multiple epochs (fit)
#  |  - Single epoch (train_epoch/test_epoch)
#  |  - Single batch (train_batch/test_batch)
#  |
#  |  Method resolution order:
#  |      Trainer
#  |      abc.ABC
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, model, loss_fn, optimizer, device=None)
#  |      Initialize the trainer.
#  |      :param model: Instance of the model to train.
#  |      :param loss_fn: The loss function to evaluate with.
#  |      :param optimizer: The optimizer to train with.
#  |      :param device: torch.device to run training on (CPU or GPU).
#  |
#  |  fit(self, dl_train: torch.utils.data.dataloader.DataLoader, dl_test: torch.utils.data.dataloader.DataLoader, num_epochs, checkpoints: str = None, early_stopping: int = None, print_every=1, **kw) -> cs236605.train_results.FitResult
#  |      Trains the model for multiple epochs with a given training set,
#  |      and calculates validation loss over a given validation set.
#  |      :param dl_train: Dataloader for the training set.
#  |      :param dl_test: Dataloader for the test set.
#  |      :param num_epochs: Number of epochs to train for.
#  |      :param checkpoints: Whether to save model to file every time the
#  |          test set accuracy improves. Should be a string containing a
#  |          filename without extension.
#  |      :param early_stopping: Whether to stop training early if there is no
#  |          test loss improvement for this number of epochs.
#  |      :param print_every: Print progress every this number of epochs.
#  |      :return: A FitResult object containing train and test losses per epoch.
#  |
#  |  test_batch(self, batch) -> cs236605.train_results.BatchResult
#  |      Runs a single batch forward through the model and calculates loss.
#  |      :param batch: A single batch of data  from a data loader (might
#  |          be a tuple of data and labels or anything else depending on
#  |          the underlying dataset.
#  |      :return: A BatchResult containing the value of the loss function and
#  |          the number of correctly classified samples in the batch.
#  |
#  |  test_epoch(self, dl_test: torch.utils.data.dataloader.DataLoader, **kw) -> cs236605.train_results.EpochResult
#  |      Evaluate model once over a test set (single epoch).
#  |      :param dl_test: DataLoader for the test set.
#  |      :param kw: Keyword args supported by _foreach_batch.
#  |      :return: An EpochResult for the epoch.
#  |
#  |  train_batch(self, batch) -> cs236605.train_results.BatchResult
#  |      Runs a single batch forward through the model, calculates loss,
#  |      preforms back-propagation and uses the optimizer to update weights.
#  |      :param batch: A single batch of data  from a data loader (might
#  |          be a tuple of data and labels or anything else depending on
#  |          the underlying dataset.
#  |      :return: A BatchResult containing the value of the loss function and
#  |          the number of correctly classified samples in the batch.
#  |
#  |  train_epoch(self, dl_train: torch.utils.data.dataloader.DataLoader, **kw) -> cs236605.train_results.EpochResult
#  |      Train once over a training set (single epoch).
#  |      :param dl_train: DataLoader for the training set.
#  |      :param kw: Keyword args supported by _foreach_batch.
#  |      :return: An EpochResult for the epoch.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __abstractmethods__ = frozenset({'test_batch', 'train_batch'})

# %% [markdown]
# The `Trainer` class splits the task of training (and evaluating) models into three conceptual levels,
# - Multiple epochs - the `fit` method, which returns a `FitResult` containing losses and accuracies for all epochs.
# - Single epoch - the `train_epoch` and `test_epoch` methods, which return an `EpochResult` containing losses per batch and the single accuracy result of the epoch.
# - Single batch - the `train_batch` and `test_batch` methods, which return a `BatchResult` containing a single loss and the number of correctly classified samples in the batch.
#
# It implements the first two levels. Inheriting classes are expected to implement the single-batch level methods since these are generally model/task specific.

# %% [markdown]
# The first thing we should do in order to verify our model, gradient calculations and optimizer implementation is to try to overfit a large model (many parameters) to a small dataset (few images). This will show us that things are working properly.
#
# Let's begin by loading the CIFAR-10 dataset.

# %%
data_dir = os.path.join(os.getenv('HOME'), '.pytorch-datasets')
ds_train = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=True, transform=tvtf.ToTensor())
ds_test = torchvision.datasets.CIFAR10(root=data_dir, download=True, train=False, transform=tvtf.ToTensor())

print(f'Train: {len(ds_train)} samples')
print(f'Test: {len(ds_test)} samples')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Train: 50000 samples
# Test: 10000 samples

# %% [markdown]
# Now, let's implement just a small part of our training logic since that's what we need right now.

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `train_batch()` method in the `BlocksTrainer` class within the `hw2/training.py` module.
# 1. Update the hyperparameter values in the `part2_overfit_hp()` function in the `hw2/answers.py` module. Tweak the hyperparameter values until your model overfits a small number of samples in the block below. You should get 100% accuracy within a few epochs.

# %%
import hw2.blocks as blocks
import hw2.models as models
import hw2.answers as answers
from torch.utils.data import DataLoader

# Overfit to a very small dataset of 20 samples
batch_size = 10
max_batches = 2
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)

# Get hyperparameters
hp = answers.part2_overfit_hp()

torch.manual_seed(seed)
model = models.MLP(3*32*32, num_classes=10, hidden_features=[128]*3, wstd=hp['wstd'])
loss_fn = blocks.CrossEntropyLoss()
optimizer = optimizers.VanillaSGD(model.params(), learn_rate=hp['lr'], reg=hp['reg'])

# Run training over small dataset multiple times
trainer = training.BlocksTrainer(model, loss_fn, optimizer)
best_acc = 0
for i in range(20):
    res = trainer.train_epoch(dl_train, max_batches=max_batches)
    best_acc = res.accuracy if res.accuracy > best_acc else best_acc
    
test.assertGreaterEqual(best_acc, 90)
# Out:
# train_batch (Avg. Loss 2.420, Accuracy 15.0): 100%|██████████| 2/2 [00:00<00:00, 11.23it/s]
# train_batch (Avg. Loss 2.070, Accuracy 20.0): 100%|██████████| 2/2 [00:00<00:00, 114.92it/s]
# train_batch (Avg. Loss 1.893, Accuracy 25.0): 100%|██████████| 2/2 [00:00<00:00, 121.14it/s]
# train_batch (Avg. Loss 1.753, Accuracy 25.0): 100%|██████████| 2/2 [00:00<00:00, 117.43it/s]
# train_batch (Avg. Loss 1.636, Accuracy 30.0): 100%|██████████| 2/2 [00:00<00:00, 97.53it/s]
# train_batch (Avg. Loss 1.523, Accuracy 30.0): 100%|██████████| 2/2 [00:00<00:00, 115.18it/s]
# train_batch (Avg. Loss 1.418, Accuracy 50.0): 100%|██████████| 2/2 [00:00<00:00, 89.47it/s]
# train_batch (Avg. Loss 1.329, Accuracy 60.0): 100%|██████████| 2/2 [00:00<00:00, 93.45it/s]
# train_batch (Avg. Loss 1.250, Accuracy 65.0): 100%|██████████| 2/2 [00:00<00:00, 92.45it/s]
# train_batch (Avg. Loss 1.179, Accuracy 70.0): 100%|██████████| 2/2 [00:00<00:00, 99.10it/s]
# train_batch (Avg. Loss 1.105, Accuracy 75.0): 100%|██████████| 2/2 [00:00<00:00, 62.06it/s]
# train_batch (Avg. Loss 1.040, Accuracy 80.0): 100%|██████████| 2/2 [00:00<00:00, 68.29it/s]
# train_batch (Avg. Loss 0.980, Accuracy 90.0): 100%|██████████| 2/2 [00:00<00:00, 91.69it/s]
# train_batch (Avg. Loss 0.922, Accuracy 90.0): 100%|██████████| 2/2 [00:00<00:00, 51.91it/s]
# train_batch (Avg. Loss 0.869, Accuracy 90.0): 100%|██████████| 2/2 [00:00<00:00, 103.85it/s]
# train_batch (Avg. Loss 0.822, Accuracy 90.0): 100%|██████████| 2/2 [00:00<00:00, 100.49it/s]
# train_batch (Avg. Loss 0.778, Accuracy 90.0): 100%|██████████| 2/2 [00:00<00:00, 105.69it/s]
# train_batch (Avg. Loss 0.733, Accuracy 95.0): 100%|██████████| 2/2 [00:00<00:00, 90.17it/s]
# train_batch (Avg. Loss 0.699, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 91.88it/s]
# train_batch (Avg. Loss 0.659, Accuracy 100.0): 100%|██████████| 2/2 [00:00<00:00, 77.72it/s]

# %% [markdown]
# Now that we know training works, let's try to fit a model to a bit more data for a few epochs, to see how well we're doing. First, we need some code to plot the FitResults object.

# %%
from cs236605.plot import plot_fit

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `test_batch()` method in the `BlocksTrainer` class within the `hw2/training.py` module.
# 1. Implement the `fit()` method of the `Trainer` class within the `hw2/training.py` module.
# 1. Tweak the hyperparameters for this section in the `part2_optim_hp()` function in the `hw2/answers.py` module.
# 1. Run the following blocks to train. Try to get above 35-40% test-set accuracy.

# %%
# Define a larger part of the CIFAR-10 dataset (still not the whole thing)
batch_size = 50
max_batches = 100
in_features = 3*32*32
num_classes = 10
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size//2, shuffle=False)

# %%
# Define a function to train a model with our Trainer and various optimizers
def train_with_optimizer(opt_name, opt_class, fig):
    torch.manual_seed(seed)
    
    # Get hyperparameters
    hp = answers.part2_optim_hp()
    hidden_features = [128] * 5
    num_epochs = 10
    
    # Create model, loss and optimizer instances
    model = models.MLP(in_features, num_classes, hidden_features, wstd=hp['wstd'])
    loss_fn = blocks.CrossEntropyLoss()
    optimizer = opt_class(model.params(), learn_rate=hp[f'lr_{opt_name}'], reg=hp['reg'])

    # Train with the Trainer
    trainer = training.BlocksTrainer(model, loss_fn, optimizer)
    fit_res = trainer.fit(dl_train, dl_test, num_epochs, max_batches=max_batches)
    
    fig, axes = plot_fit(fit_res, fig=fig, legend=opt_name)
    return fig

# %%
fig_optim = None
fig_optim = train_with_optimizer('vanilla', optimizers.VanillaSGD, fig_optim)
# Out:
# Early stopping -  None
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.213, Accuracy 19.0): 100%|██████████| 100/100 [00:01<00:00, 53.16it/s]
# test_batch (Avg. Loss 2.140, Accuracy 22.6): 100%|██████████| 100/100 [00:00<00:00, 110.25it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.054, Accuracy 25.8): 100%|██████████| 100/100 [00:01<00:00, 55.47it/s]
# test_batch (Avg. Loss 2.036, Accuracy 26.5): 100%|██████████| 100/100 [00:01<00:00, 97.43it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.959, Accuracy 29.3): 100%|██████████| 100/100 [00:01<00:00, 58.38it/s]
# test_batch (Avg. Loss 1.982, Accuracy 28.6): 100%|██████████| 100/100 [00:01<00:00, 87.23it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.903, Accuracy 31.1): 100%|██████████| 100/100 [00:02<00:00, 45.45it/s]
# test_batch (Avg. Loss 1.958, Accuracy 29.0): 100%|██████████| 100/100 [00:01<00:00, 89.53it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.863, Accuracy 32.8): 100%|██████████| 100/100 [00:01<00:00, 53.75it/s]
# test_batch (Avg. Loss 1.933, Accuracy 30.0): 100%|██████████| 100/100 [00:00<00:00, 104.17it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.829, Accuracy 34.2): 100%|██████████| 100/100 [00:01<00:00, 51.30it/s]
# test_batch (Avg. Loss 1.908, Accuracy 31.2): 100%|██████████| 100/100 [00:01<00:00, 99.11it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.800, Accuracy 36.0): 100%|██████████| 100/100 [00:02<00:00, 45.62it/s]
# test_batch (Avg. Loss 1.891, Accuracy 32.2): 100%|██████████| 100/100 [00:00<00:00, 100.77it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.773, Accuracy 36.7): 100%|██████████| 100/100 [00:01<00:00, 54.55it/s]
# test_batch (Avg. Loss 1.876, Accuracy 32.7): 100%|██████████| 100/100 [00:01<00:00, 96.87it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.748, Accuracy 37.7): 100%|██████████| 100/100 [00:01<00:00, 57.80it/s]
# test_batch (Avg. Loss 1.862, Accuracy 33.1): 100%|██████████| 100/100 [00:00<00:00, 110.55it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.724, Accuracy 38.3): 100%|██████████| 100/100 [00:01<00:00, 57.85it/s]
# test_batch (Avg. Loss 1.849, Accuracy 34.2): 100%|██████████| 100/100 [00:00<00:00, 118.44it/s]

# %% [markdown]
# ## Momentum
# <a id=part2_4></a>

# %% [markdown]
# The simple vanilla SGD update is rarely used in practice since it's very slow to converge relative to other optimization algorithms.
#
# One reason is that naïvely updating in the direction of the current gradient causes it to fluctuate wildly in areas of the loss surface where some dimensions are much steeper than others.
# Another reason is that using the same learning rate for all parameters is not a great idea since not all parameters are created equal. For example, parameters associated with rare features should be updated with a larger step than ones associated with commonly-occurring features because they'll get less updates through the gradients.
#
# Therefore more advanced optimizers take into account the previous gradients of a parameter and/or try to use a per-parameter specific learning rate instead of a common one.

# %% [markdown]
# Let's now implement a simple and common optimizer: SGD with Momentum. This optimizer takes **previous gradients** of a parameter into account when updating it's value instead of just the current one. In practice it usually provides faster convergence than the vanilla SGD.
#
# The SGD with Momentum update rule can be stated as follows:
# $$\begin{align}
# \vec{v}_{t+1} &= \mu \vec{v}_t - \eta \delta \vec{\theta}_t \\
# \vec{\theta}_{t+1} &= \vec{\theta}_t + \vec{v}_{t+1}
# \end{align}$$
#
# Where $\eta$ is the learning rate,
# $\vec{\theta}$ is a model parameter,
# $\delta \vec{\theta}_t=\pderiv{L}{\vec{\theta}}(\vec{\theta}_t)$ is the gradient of the loss w.r.t. to the parameter and $\mu$ is a hyperparameter known as momentum.
#
# Expanding the update rule recursively shows us now the parameter update infact depends on all previous gradient values for that parameter, where the old gradients are exponentially decayed by a factor of $\mu$ at each timestep.
#
# Since we're incorporating previous gradient (update directions), a noisy value of the current gradient will have less effect so that the general direction of previous updates is maintained somewhat. The following figure illustrates this.
#
# <img src="imgs/sgd-momentum.png" width="600" />

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `MomentumSGD` class in the `hw2/optimizers.py` module.
# 1. Tweak the learning rate for momentum in `part2_optim_hp()` the function in the `hw2/answers.py` module.
# 1. Run the following block to compare to the vanilla SGD.

# %%
fig_optim = train_with_optimizer('momentum', optimizers.MomentumSGD, fig_optim)
fig_optim
# Out:
# Early stopping -  None
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.193, Accuracy 18.7): 100%|██████████| 100/100 [00:01<00:00, 57.08it/s]
# test_batch (Avg. Loss 2.057, Accuracy 23.7): 100%|██████████| 100/100 [00:00<00:00, 113.78it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 1.957, Accuracy 28.5): 100%|██████████| 100/100 [00:01<00:00, 54.22it/s]
# test_batch (Avg. Loss 1.941, Accuracy 28.3): 100%|██████████| 100/100 [00:00<00:00, 114.02it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.862, Accuracy 31.6): 100%|██████████| 100/100 [00:02<00:00, 47.83it/s]
# test_batch (Avg. Loss 1.913, Accuracy 31.3): 100%|██████████| 100/100 [00:00<00:00, 98.52it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.795, Accuracy 34.2): 100%|██████████| 100/100 [00:02<00:00, 46.26it/s]
# test_batch (Avg. Loss 1.880, Accuracy 31.6): 100%|██████████| 100/100 [00:01<00:00, 101.56it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.762, Accuracy 37.0): 100%|██████████| 100/100 [00:02<00:00, 47.08it/s]
# test_batch (Avg. Loss 1.889, Accuracy 33.2): 100%|██████████| 100/100 [00:01<00:00, 99.21it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.712, Accuracy 38.9): 100%|██████████| 100/100 [00:01<00:00, 52.25it/s]
# test_batch (Avg. Loss 1.854, Accuracy 34.4): 100%|██████████| 100/100 [00:01<00:00, 97.48it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.664, Accuracy 40.1): 100%|██████████| 100/100 [00:01<00:00, 53.30it/s]
# test_batch (Avg. Loss 1.798, Accuracy 37.0): 100%|██████████| 100/100 [00:00<00:00, 114.33it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.613, Accuracy 42.2): 100%|██████████| 100/100 [00:01<00:00, 53.66it/s]
# test_batch (Avg. Loss 1.810, Accuracy 36.7): 100%|██████████| 100/100 [00:01<00:00, 96.17it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.567, Accuracy 44.0): 100%|██████████| 100/100 [00:01<00:00, 55.22it/s]
# test_batch (Avg. Loss 1.782, Accuracy 37.2): 100%|██████████| 100/100 [00:01<00:00, 96.02it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.521, Accuracy 45.3): 100%|██████████| 100/100 [00:01<00:00, 53.62it/s]
# test_batch (Avg. Loss 1.796, Accuracy 37.8): 100%|██████████| 100/100 [00:00<00:00, 115.74it/s]

# %% [markdown]
# ## RMSProp
# <a id=part2_5></a>

# %% [markdown]
# This is another optmizer that accounts for previous gradients, but this time it uses them to adapt the learning rate per parameter.
#
# RMSProp maintains a decaying moving average of previous squared gradients,
# $$
# \vec{r}_{t+1} = \gamma\vec{r}_{t} + (1-\gamma)\delta\vec{\theta}_t^2
# $$
#
# where $0<\gamma<1$ is a decay constant usually set close to $1$. The update rule for each parameter is then,
# $$
# \vec{\theta}_{t+1} = \vec{\theta}_t - \left( \frac{\eta}{\sqrt{r_{t+1}+\varepsilon}} \right) \delta\vec{\theta}_t
# $$
#
# where $\varepsilon$ is a small constant to prevent numerical instability. The idea here is to decrease the learning rate for parameters with high gradient values and vice-versa. The decaying moving average prevents accumulating all the past gradients which would cause the effective learning rate to become zero.

# %% [markdown]
# **TODO**:
# 1. Complete the implementation of the `RMSProp` class in the `hw2/optimizers.py` module.
# 1. Tweak the learning rate for RMSProp in `part2_optim_hp()` the function in the `hw2/answers.py` module.
# 1. Run the following block to compare to the other optimizers.

# %%
fig_optim = train_with_optimizer('rmsprop', optimizers.RMSProp, fig_optim)
fig_optim
# Out:
# Early stopping -  None
# --- EPOCH 1/10 ---
# train_batch (Avg. Loss 2.333, Accuracy 15.6): 100%|██████████| 100/100 [00:02<00:00, 45.82it/s]
# test_batch (Avg. Loss 2.149, Accuracy 21.5): 100%|██████████| 100/100 [00:00<00:00, 118.85it/s]
# --- EPOCH 2/10 ---
# train_batch (Avg. Loss 2.093, Accuracy 23.0): 100%|██████████| 100/100 [00:02<00:00, 47.50it/s]
# test_batch (Avg. Loss 2.032, Accuracy 28.7): 100%|██████████| 100/100 [00:00<00:00, 124.62it/s]
# --- EPOCH 3/10 ---
# train_batch (Avg. Loss 1.944, Accuracy 29.6): 100%|██████████| 100/100 [00:02<00:00, 45.63it/s]
# test_batch (Avg. Loss 1.915, Accuracy 32.0): 100%|██████████| 100/100 [00:01<00:00, 97.69it/s]
# --- EPOCH 4/10 ---
# train_batch (Avg. Loss 1.863, Accuracy 31.8): 100%|██████████| 100/100 [00:02<00:00, 39.84it/s]
# test_batch (Avg. Loss 1.887, Accuracy 32.5): 100%|██████████| 100/100 [00:00<00:00, 101.14it/s]
# --- EPOCH 5/10 ---
# train_batch (Avg. Loss 1.794, Accuracy 35.4): 100%|██████████| 100/100 [00:02<00:00, 38.33it/s]
# test_batch (Avg. Loss 1.843, Accuracy 33.6): 100%|██████████| 100/100 [00:00<00:00, 113.69it/s]
# --- EPOCH 6/10 ---
# train_batch (Avg. Loss 1.738, Accuracy 37.5): 100%|██████████| 100/100 [00:02<00:00, 40.39it/s]
# test_batch (Avg. Loss 2.029, Accuracy 29.9): 100%|██████████| 100/100 [00:00<00:00, 103.58it/s]
# --- EPOCH 7/10 ---
# train_batch (Avg. Loss 1.690, Accuracy 39.9): 100%|██████████| 100/100 [00:02<00:00, 39.78it/s]
# test_batch (Avg. Loss 1.901, Accuracy 32.9): 100%|██████████| 100/100 [00:00<00:00, 111.47it/s]
# --- EPOCH 8/10 ---
# train_batch (Avg. Loss 1.642, Accuracy 41.1): 100%|██████████| 100/100 [00:02<00:00, 39.89it/s]
# test_batch (Avg. Loss 1.880, Accuracy 33.6): 100%|██████████| 100/100 [00:00<00:00, 111.29it/s]
# --- EPOCH 9/10 ---
# train_batch (Avg. Loss 1.594, Accuracy 43.2): 100%|██████████| 100/100 [00:02<00:00, 37.39it/s]
# test_batch (Avg. Loss 1.909, Accuracy 34.1): 100%|██████████| 100/100 [00:00<00:00, 106.34it/s]
# --- EPOCH 10/10 ---
# train_batch (Avg. Loss 1.547, Accuracy 45.0): 100%|██████████| 100/100 [00:02<00:00, 40.85it/s]
# test_batch (Avg. Loss 1.867, Accuracy 35.0): 100%|██████████| 100/100 [00:01<00:00, 88.34it/s]

# %% [markdown]
# ## Dropout Regularization
# <a id=part2_6></a>

# %% [markdown]
# [Dropout](http://jmlr.org/papers/volume15/srivastava14a.old/srivastava14a.pdf) is a useful technique to improve generalization of deep models.
#
# The idea is simple: during the forward pass, drop (set to to zero) the activation of each neuron, with a probability of $p$. For example, if $p=5$ this means we drop half the activations on average.
#
# There are a few important things to note about dropout:
# 1. It is only performed during training. When testing our model the dropout layers should be a no-op.
# 1. In the backward pass, gradients are only propagated back into neurons that weren't dropped during the forward pass.
# 1. During testing, the activations must be scaled since the expected value of each neuron during the training phase is now $p$ times it's original expectation. Thus, we need to scale the test-time activations by $p$ to match. Equivalently, we can scale the test time activations by $1/p$.

# %% [markdown]
# **TODO**: Complete the implementation of the `Dropout` class in the `hw2/blocks.py` module.

# %%
from hw2.grad_compare import compare_block_to_torch

# Check architecture of MLP with dropout layers
mlp_dropout = models.MLP(in_features, num_classes, [50]*3, dropout=0.5)
print(mlp_dropout)
test.assertEqual(len(mlp_dropout.sequence), 10)
for b1, b2 in zip(mlp_dropout.sequence, mlp_dropout.sequence[1:]):
    if isinstance(b1, blocks.ReLU):
        test.assertIsInstance(b2, blocks.Dropout)
test.assertIsInstance(mlp_dropout.sequence[-1], blocks.Linear)

# Test end-to-end gradient in train and test modes.
mlp_dropout.train(True)
for diff in compare_block_to_torch(mlp_dropout, torch.randn(500, in_features)):
    test.assertLess(diff, 1e-2)
    
mlp_dropout.train(False)
for diff in compare_block_to_torch(mlp_dropout, torch.randn(500, in_features)):
    test.assertLess(diff, 1e-2)
# Out:
# MLP, Sequential
# 	[0] Linear(3072, 50)
# 	[1] ReLU
# 	[2] Dropout(p=0.5)
# 	[3] Linear(50, 50)
# 	[4] ReLU
# 	[5] Dropout(p=0.5)
# 	[6] Linear(50, 50)
# 	[7] ReLU
# 	[8] Dropout(p=0.5)
# 	[9] Linear(50, 10)
#
# Comparing gradients...
# input    diff=0.000
# param#01 diff=0.000
# param#02 diff=0.000
# param#03 diff=0.000
# param#04 diff=0.000
# param#05 diff=0.000
# param#06 diff=0.000
# param#07 diff=0.000
# param#08 diff=0.000
# Comparing gradients...
# input    diff=0.000
# param#01 diff=0.000
# param#02 diff=0.000
# param#03 diff=0.000
# param#04 diff=0.000
# param#05 diff=0.000
# param#06 diff=0.000
# param#07 diff=0.000
# param#08 diff=0.000

# %% [markdown]
# To see whether dropout really improves generalization, let's take a small training set
# (small enough to overfit) and a large test set and check whether we get less overfitting and
# perhaps improved test-set accuracy when using dropout.

# %%
# Define a small set from CIFAR-10, but take a larger test set since we want to test generalization
batch_size = 10
max_batches = 40
in_features = 3*32*32
num_classes = 10
dl_train = torch.utils.data.DataLoader(ds_train, batch_size, shuffle=False)
dl_test = torch.utils.data.DataLoader(ds_test, batch_size*2, shuffle=False)

# %%
# Get hyperparameters
hp = answers.part2_dropout_hp()
hidden_features = [400] * 1
num_epochs = 30

# %% [markdown]
# **TODO**:
# Tweak the hyperparameters for this section in the `part2_dropout_hp()` function in the `hw2/answers.py` module. Try to set them so that the first model (with `dropout`=0) overfits. You can disable the other dropout options until you tune the hyperparameters. We can then see the effect of dropout for generalization.

# %%
torch.manual_seed(seed)
fig=None
for dropout in [0, 0.4, 0.8]:
    model = models.MLP(in_features, num_classes, hidden_features, wstd=hp['wstd'], dropout=dropout)
    loss_fn = blocks.CrossEntropyLoss()
    optimizer = optimizers.MomentumSGD(model.params(), learn_rate=hp['lr'], reg=0)

    print('*** Training with dropout=', dropout)
    trainer = training.BlocksTrainer(model, loss_fn, optimizer)
    fit_res_dropout = trainer.fit(dl_train, dl_test, num_epochs, max_batches=max_batches, print_every=6)
    fig, axes = plot_fit(fit_res_dropout, fig=fig, legend=f'dropout={dropout}', log_loss=True)
# Out:
# *** Training with dropout= 0
# Early stopping -  None
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 3.720, Accuracy 13.2): 100%|██████████| 40/40 [00:00<00:00, 76.64it/s]
# test_batch (Avg. Loss 3.206, Accuracy 18.2): 100%|██████████| 40/40 [00:00<00:00, 130.23it/s]
# train_batch (Avg. Loss 2.391, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 86.81it/s]
# test_batch (Avg. Loss 2.634, Accuracy 19.8): 100%|██████████| 40/40 [00:00<00:00, 113.65it/s]
# train_batch (Avg. Loss 1.938, Accuracy 34.5): 100%|██████████| 40/40 [00:00<00:00, 77.09it/s]
# test_batch (Avg. Loss 2.622, Accuracy 20.8): 100%|██████████| 40/40 [00:00<00:00, 114.19it/s]
# train_batch (Avg. Loss 1.714, Accuracy 40.5): 100%|██████████| 40/40 [00:00<00:00, 68.72it/s]
# test_batch (Avg. Loss 2.707, Accuracy 19.9): 100%|██████████| 40/40 [00:00<00:00, 73.16it/s]
# train_batch (Avg. Loss 1.558, Accuracy 43.2): 100%|██████████| 40/40 [00:00<00:00, 77.72it/s]
# test_batch (Avg. Loss 2.722, Accuracy 19.4): 100%|██████████| 40/40 [00:00<00:00, 87.88it/s]
# train_batch (Avg. Loss 1.443, Accuracy 49.5): 100%|██████████| 40/40 [00:00<00:00, 79.09it/s]
# test_batch (Avg. Loss 2.660, Accuracy 20.0): 100%|██████████| 40/40 [00:00<00:00, 99.29it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.337, Accuracy 55.2): 100%|██████████| 40/40 [00:00<00:00, 70.89it/s]
# test_batch (Avg. Loss 2.581, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 97.04it/s]
# train_batch (Avg. Loss 1.221, Accuracy 58.5): 100%|██████████| 40/40 [00:00<00:00, 69.82it/s]
# test_batch (Avg. Loss 2.544, Accuracy 22.4): 100%|██████████| 40/40 [00:00<00:00, 107.60it/s]
# train_batch (Avg. Loss 1.117, Accuracy 65.0): 100%|██████████| 40/40 [00:00<00:00, 68.49it/s]
# test_batch (Avg. Loss 2.557, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 101.39it/s]
# train_batch (Avg. Loss 1.035, Accuracy 68.8): 100%|██████████| 40/40 [00:00<00:00, 65.19it/s]
# test_batch (Avg. Loss 2.589, Accuracy 23.6): 100%|██████████| 40/40 [00:00<00:00, 97.70it/s]
# train_batch (Avg. Loss 0.955, Accuracy 72.2): 100%|██████████| 40/40 [00:00<00:00, 72.06it/s]
# test_batch (Avg. Loss 2.626, Accuracy 23.9): 100%|██████████| 40/40 [00:00<00:00, 101.03it/s]
# train_batch (Avg. Loss 0.885, Accuracy 75.2): 100%|██████████| 40/40 [00:00<00:00, 84.02it/s]
# test_batch (Avg. Loss 2.636, Accuracy 23.8): 100%|██████████| 40/40 [00:00<00:00, 141.22it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 0.819, Accuracy 78.8): 100%|██████████| 40/40 [00:00<00:00, 79.56it/s]
# test_batch (Avg. Loss 2.635, Accuracy 23.6): 100%|██████████| 40/40 [00:00<00:00, 115.34it/s]
# train_batch (Avg. Loss 0.763, Accuracy 81.2): 100%|██████████| 40/40 [00:00<00:00, 79.04it/s]
# test_batch (Avg. Loss 2.642, Accuracy 23.9): 100%|██████████| 40/40 [00:00<00:00, 147.73it/s]
# train_batch (Avg. Loss 0.714, Accuracy 83.5): 100%|██████████| 40/40 [00:00<00:00, 91.44it/s]
# test_batch (Avg. Loss 2.645, Accuracy 23.8): 100%|██████████| 40/40 [00:00<00:00, 132.45it/s]
# train_batch (Avg. Loss 0.672, Accuracy 85.0): 100%|██████████| 40/40 [00:00<00:00, 95.92it/s]
# test_batch (Avg. Loss 2.651, Accuracy 22.9): 100%|██████████| 40/40 [00:00<00:00, 153.63it/s]
# train_batch (Avg. Loss 0.633, Accuracy 86.0): 100%|██████████| 40/40 [00:00<00:00, 88.94it/s]
# test_batch (Avg. Loss 2.652, Accuracy 22.6): 100%|██████████| 40/40 [00:00<00:00, 147.26it/s]
# train_batch (Avg. Loss 0.599, Accuracy 87.8): 100%|██████████| 40/40 [00:00<00:00, 88.84it/s]
# test_batch (Avg. Loss 2.660, Accuracy 22.1): 100%|██████████| 40/40 [00:00<00:00, 149.44it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.565, Accuracy 88.5): 100%|██████████| 40/40 [00:00<00:00, 91.51it/s]
# test_batch (Avg. Loss 2.676, Accuracy 22.1): 100%|██████████| 40/40 [00:00<00:00, 136.34it/s]
# train_batch (Avg. Loss 0.535, Accuracy 89.5): 100%|██████████| 40/40 [00:00<00:00, 93.28it/s]
# test_batch (Avg. Loss 2.688, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 160.11it/s]
# train_batch (Avg. Loss 0.508, Accuracy 90.2): 100%|██████████| 40/40 [00:00<00:00, 97.83it/s]
# test_batch (Avg. Loss 2.702, Accuracy 22.6): 100%|██████████| 40/40 [00:00<00:00, 117.39it/s]
# train_batch (Avg. Loss 0.483, Accuracy 91.5): 100%|██████████| 40/40 [00:00<00:00, 87.74it/s]
# test_batch (Avg. Loss 2.720, Accuracy 21.9): 100%|██████████| 40/40 [00:00<00:00, 143.70it/s]
# train_batch (Avg. Loss 0.462, Accuracy 92.0): 100%|██████████| 40/40 [00:00<00:00, 70.92it/s]
# test_batch (Avg. Loss 2.733, Accuracy 21.9): 100%|██████████| 40/40 [00:00<00:00, 114.11it/s]
# train_batch (Avg. Loss 0.443, Accuracy 93.2): 100%|██████████| 40/40 [00:00<00:00, 74.75it/s]
# test_batch (Avg. Loss 2.758, Accuracy 21.5): 100%|██████████| 40/40 [00:00<00:00, 110.01it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.427, Accuracy 93.2): 100%|██████████| 40/40 [00:00<00:00, 88.12it/s]
# test_batch (Avg. Loss 2.764, Accuracy 22.2): 100%|██████████| 40/40 [00:00<00:00, 125.93it/s]
# train_batch (Avg. Loss 0.412, Accuracy 93.5): 100%|██████████| 40/40 [00:00<00:00, 66.05it/s]
# test_batch (Avg. Loss 2.790, Accuracy 21.9): 100%|██████████| 40/40 [00:00<00:00, 105.14it/s]
# train_batch (Avg. Loss 0.401, Accuracy 93.8): 100%|██████████| 40/40 [00:00<00:00, 70.57it/s]
# test_batch (Avg. Loss 2.812, Accuracy 22.4): 100%|██████████| 40/40 [00:00<00:00, 121.04it/s]
# train_batch (Avg. Loss 0.390, Accuracy 94.0): 100%|██████████| 40/40 [00:00<00:00, 74.65it/s]
# test_batch (Avg. Loss 2.838, Accuracy 22.1): 100%|██████████| 40/40 [00:00<00:00, 128.33it/s]
# train_batch (Avg. Loss 0.383, Accuracy 95.0): 100%|██████████| 40/40 [00:00<00:00, 81.53it/s]
# test_batch (Avg. Loss 2.869, Accuracy 22.8): 100%|██████████| 40/40 [00:00<00:00, 117.22it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.374, Accuracy 94.8): 100%|██████████| 40/40 [00:00<00:00, 80.12it/s]
# test_batch (Avg. Loss 2.907, Accuracy 22.5): 100%|██████████| 40/40 [00:00<00:00, 130.47it/s]
# *** Training with dropout= 0.4
# Early stopping -  None
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 6.909, Accuracy 13.5): 100%|██████████| 40/40 [00:00<00:00, 88.44it/s]
# test_batch (Avg. Loss 2.971, Accuracy 15.4): 100%|██████████| 40/40 [00:00<00:00, 119.67it/s]
# train_batch (Avg. Loss 2.891, Accuracy 20.0): 100%|██████████| 40/40 [00:00<00:00, 80.05it/s]
# test_batch (Avg. Loss 2.203, Accuracy 19.9): 100%|██████████| 40/40 [00:00<00:00, 126.69it/s]
# train_batch (Avg. Loss 2.260, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 88.81it/s]
# test_batch (Avg. Loss 2.145, Accuracy 22.1): 100%|██████████| 40/40 [00:00<00:00, 138.71it/s]
# train_batch (Avg. Loss 2.102, Accuracy 23.8): 100%|██████████| 40/40 [00:00<00:00, 82.47it/s]
# test_batch (Avg. Loss 2.113, Accuracy 25.0): 100%|██████████| 40/40 [00:00<00:00, 129.39it/s]
# train_batch (Avg. Loss 2.027, Accuracy 28.0): 100%|██████████| 40/40 [00:00<00:00, 86.07it/s]
# test_batch (Avg. Loss 2.088, Accuracy 26.1): 100%|██████████| 40/40 [00:00<00:00, 134.52it/s]
# train_batch (Avg. Loss 1.914, Accuracy 31.2): 100%|██████████| 40/40 [00:00<00:00, 74.29it/s]
# test_batch (Avg. Loss 2.094, Accuracy 26.0): 100%|██████████| 40/40 [00:00<00:00, 107.32it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.925, Accuracy 33.5): 100%|██████████| 40/40 [00:00<00:00, 81.12it/s]
# test_batch (Avg. Loss 2.067, Accuracy 25.4): 100%|██████████| 40/40 [00:00<00:00, 118.38it/s]
# train_batch (Avg. Loss 1.874, Accuracy 34.8): 100%|██████████| 40/40 [00:00<00:00, 82.43it/s]
# test_batch (Avg. Loss 2.085, Accuracy 26.1): 100%|██████████| 40/40 [00:00<00:00, 136.73it/s]
# train_batch (Avg. Loss 1.807, Accuracy 35.2): 100%|██████████| 40/40 [00:00<00:00, 60.92it/s]
# test_batch (Avg. Loss 2.065, Accuracy 27.5): 100%|██████████| 40/40 [00:00<00:00, 103.83it/s]
# train_batch (Avg. Loss 1.747, Accuracy 38.2): 100%|██████████| 40/40 [00:00<00:00, 76.15it/s]
# test_batch (Avg. Loss 2.035, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 122.54it/s]
# train_batch (Avg. Loss 1.691, Accuracy 37.8): 100%|██████████| 40/40 [00:00<00:00, 83.36it/s]
# test_batch (Avg. Loss 2.053, Accuracy 26.6): 100%|██████████| 40/40 [00:00<00:00, 148.71it/s]
# train_batch (Avg. Loss 1.723, Accuracy 36.8): 100%|██████████| 40/40 [00:00<00:00, 78.04it/s]
# test_batch (Avg. Loss 2.040, Accuracy 28.9): 100%|██████████| 40/40 [00:00<00:00, 111.27it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 1.643, Accuracy 40.0): 100%|██████████| 40/40 [00:00<00:00, 67.57it/s]
# test_batch (Avg. Loss 2.027, Accuracy 28.4): 100%|██████████| 40/40 [00:00<00:00, 101.02it/s]
# train_batch (Avg. Loss 1.587, Accuracy 46.0): 100%|██████████| 40/40 [00:00<00:00, 67.18it/s]
# test_batch (Avg. Loss 2.038, Accuracy 29.2): 100%|██████████| 40/40 [00:00<00:00, 91.58it/s]
# train_batch (Avg. Loss 1.609, Accuracy 44.0): 100%|██████████| 40/40 [00:00<00:00, 62.81it/s]
# test_batch (Avg. Loss 2.013, Accuracy 29.4): 100%|██████████| 40/40 [00:00<00:00, 115.99it/s]
# train_batch (Avg. Loss 1.624, Accuracy 38.8): 100%|██████████| 40/40 [00:00<00:00, 75.37it/s]
# test_batch (Avg. Loss 2.023, Accuracy 28.6): 100%|██████████| 40/40 [00:00<00:00, 95.12it/s]
# train_batch (Avg. Loss 1.479, Accuracy 47.5): 100%|██████████| 40/40 [00:00<00:00, 78.67it/s]
# test_batch (Avg. Loss 2.018, Accuracy 30.1): 100%|██████████| 40/40 [00:00<00:00, 112.12it/s]
# train_batch (Avg. Loss 1.508, Accuracy 46.5): 100%|██████████| 40/40 [00:00<00:00, 74.86it/s]
# test_batch (Avg. Loss 2.023, Accuracy 29.4): 100%|██████████| 40/40 [00:00<00:00, 104.42it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 1.476, Accuracy 48.0): 100%|██████████| 40/40 [00:00<00:00, 73.72it/s]
# test_batch (Avg. Loss 2.037, Accuracy 27.9): 100%|██████████| 40/40 [00:00<00:00, 108.67it/s]
# train_batch (Avg. Loss 1.469, Accuracy 48.8): 100%|██████████| 40/40 [00:00<00:00, 69.11it/s]
# test_batch (Avg. Loss 2.023, Accuracy 30.1): 100%|██████████| 40/40 [00:00<00:00, 108.05it/s]
# train_batch (Avg. Loss 1.432, Accuracy 50.2): 100%|██████████| 40/40 [00:00<00:00, 90.97it/s]
# test_batch (Avg. Loss 2.023, Accuracy 30.8): 100%|██████████| 40/40 [00:00<00:00, 146.06it/s]
# train_batch (Avg. Loss 1.420, Accuracy 51.5): 100%|██████████| 40/40 [00:00<00:00, 93.83it/s]
# test_batch (Avg. Loss 2.004, Accuracy 29.9): 100%|██████████| 40/40 [00:00<00:00, 154.93it/s]
# train_batch (Avg. Loss 1.416, Accuracy 50.5): 100%|██████████| 40/40 [00:00<00:00, 97.63it/s]
# test_batch (Avg. Loss 2.033, Accuracy 30.9): 100%|██████████| 40/40 [00:00<00:00, 138.61it/s]
# train_batch (Avg. Loss 1.389, Accuracy 50.5): 100%|██████████| 40/40 [00:00<00:00, 81.44it/s]
# test_batch (Avg. Loss 2.016, Accuracy 29.9): 100%|██████████| 40/40 [00:00<00:00, 119.59it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 1.380, Accuracy 52.5): 100%|██████████| 40/40 [00:00<00:00, 95.27it/s]
# test_batch (Avg. Loss 2.025, Accuracy 30.1): 100%|██████████| 40/40 [00:00<00:00, 135.59it/s]
# train_batch (Avg. Loss 1.294, Accuracy 55.2): 100%|██████████| 40/40 [00:00<00:00, 81.41it/s]
# test_batch (Avg. Loss 2.039, Accuracy 28.5): 100%|██████████| 40/40 [00:00<00:00, 141.04it/s]
# train_batch (Avg. Loss 1.297, Accuracy 55.5): 100%|██████████| 40/40 [00:00<00:00, 83.06it/s]
# test_batch (Avg. Loss 2.025, Accuracy 28.8): 100%|██████████| 40/40 [00:00<00:00, 136.19it/s]
# train_batch (Avg. Loss 1.314, Accuracy 56.8): 100%|██████████| 40/40 [00:00<00:00, 89.23it/s]
# test_batch (Avg. Loss 2.037, Accuracy 30.6): 100%|██████████| 40/40 [00:00<00:00, 137.75it/s]
# train_batch (Avg. Loss 1.372, Accuracy 51.5): 100%|██████████| 40/40 [00:00<00:00, 87.21it/s]
# test_batch (Avg. Loss 2.026, Accuracy 30.9): 100%|██████████| 40/40 [00:00<00:00, 137.24it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 1.297, Accuracy 56.2): 100%|██████████| 40/40 [00:00<00:00, 84.56it/s]
# test_batch (Avg. Loss 2.026, Accuracy 27.6): 100%|██████████| 40/40 [00:00<00:00, 144.67it/s]
# *** Training with dropout= 0.8
# Early stopping -  None
# --- EPOCH 1/30 ---
# train_batch (Avg. Loss 4.534, Accuracy 14.0): 100%|██████████| 40/40 [00:00<00:00, 77.40it/s]
# test_batch (Avg. Loss 3.258, Accuracy 15.2): 100%|██████████| 40/40 [00:00<00:00, 145.45it/s]
# train_batch (Avg. Loss 2.663, Accuracy 21.2): 100%|██████████| 40/40 [00:00<00:00, 88.03it/s]
# test_batch (Avg. Loss 2.609, Accuracy 18.9): 100%|██████████| 40/40 [00:00<00:00, 149.28it/s]
# train_batch (Avg. Loss 2.163, Accuracy 29.5): 100%|██████████| 40/40 [00:00<00:00, 82.11it/s]
# test_batch (Avg. Loss 2.371, Accuracy 21.1): 100%|██████████| 40/40 [00:00<00:00, 140.49it/s]
# train_batch (Avg. Loss 1.825, Accuracy 34.2): 100%|██████████| 40/40 [00:00<00:00, 73.17it/s]
# test_batch (Avg. Loss 2.323, Accuracy 22.0): 100%|██████████| 40/40 [00:00<00:00, 115.78it/s]
# train_batch (Avg. Loss 1.703, Accuracy 39.0): 100%|██████████| 40/40 [00:00<00:00, 95.51it/s]
# test_batch (Avg. Loss 2.229, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 112.09it/s]
# train_batch (Avg. Loss 1.550, Accuracy 45.8): 100%|██████████| 40/40 [00:00<00:00, 79.78it/s]
# test_batch (Avg. Loss 2.236, Accuracy 23.0): 100%|██████████| 40/40 [00:00<00:00, 147.99it/s]
# --- EPOCH 7/30 ---
# train_batch (Avg. Loss 1.483, Accuracy 47.8): 100%|██████████| 40/40 [00:00<00:00, 72.51it/s]
# test_batch (Avg. Loss 2.215, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 160.55it/s]
# train_batch (Avg. Loss 1.417, Accuracy 51.8): 100%|██████████| 40/40 [00:00<00:00, 76.19it/s]
# test_batch (Avg. Loss 2.205, Accuracy 24.0): 100%|██████████| 40/40 [00:00<00:00, 123.87it/s]
# train_batch (Avg. Loss 1.308, Accuracy 56.8): 100%|██████████| 40/40 [00:00<00:00, 96.28it/s]
# test_batch (Avg. Loss 2.237, Accuracy 25.0): 100%|██████████| 40/40 [00:00<00:00, 95.74it/s]
# train_batch (Avg. Loss 1.291, Accuracy 54.5): 100%|██████████| 40/40 [00:00<00:00, 98.36it/s]
# test_batch (Avg. Loss 2.219, Accuracy 24.2): 100%|██████████| 40/40 [00:00<00:00, 124.56it/s]
# train_batch (Avg. Loss 1.197, Accuracy 61.0): 100%|██████████| 40/40 [00:00<00:00, 82.65it/s]
# test_batch (Avg. Loss 2.269, Accuracy 25.2): 100%|██████████| 40/40 [00:00<00:00, 131.04it/s]
# train_batch (Avg. Loss 1.176, Accuracy 58.5): 100%|██████████| 40/40 [00:00<00:00, 73.46it/s]
# test_batch (Avg. Loss 2.214, Accuracy 24.6): 100%|██████████| 40/40 [00:00<00:00, 145.85it/s]
# --- EPOCH 13/30 ---
# train_batch (Avg. Loss 1.121, Accuracy 62.2): 100%|██████████| 40/40 [00:00<00:00, 78.74it/s]
# test_batch (Avg. Loss 2.251, Accuracy 25.6): 100%|██████████| 40/40 [00:00<00:00, 123.30it/s]
# train_batch (Avg. Loss 1.079, Accuracy 66.8): 100%|██████████| 40/40 [00:00<00:00, 84.88it/s]
# test_batch (Avg. Loss 2.294, Accuracy 24.5): 100%|██████████| 40/40 [00:00<00:00, 103.42it/s]
# train_batch (Avg. Loss 1.005, Accuracy 70.0): 100%|██████████| 40/40 [00:00<00:00, 85.09it/s]
# test_batch (Avg. Loss 2.281, Accuracy 24.1): 100%|██████████| 40/40 [00:00<00:00, 87.58it/s]
# train_batch (Avg. Loss 0.949, Accuracy 70.5): 100%|██████████| 40/40 [00:00<00:00, 83.98it/s]
# test_batch (Avg. Loss 2.292, Accuracy 25.9): 100%|██████████| 40/40 [00:00<00:00, 129.52it/s]
# train_batch (Avg. Loss 0.924, Accuracy 72.2): 100%|██████████| 40/40 [00:00<00:00, 89.82it/s]
# test_batch (Avg. Loss 2.281, Accuracy 25.4): 100%|██████████| 40/40 [00:00<00:00, 107.19it/s]
# train_batch (Avg. Loss 0.889, Accuracy 72.5): 100%|██████████| 40/40 [00:00<00:00, 76.11it/s]
# test_batch (Avg. Loss 2.262, Accuracy 25.0): 100%|██████████| 40/40 [00:00<00:00, 114.98it/s]
# --- EPOCH 19/30 ---
# train_batch (Avg. Loss 0.828, Accuracy 75.5): 100%|██████████| 40/40 [00:00<00:00, 87.45it/s]
# test_batch (Avg. Loss 2.314, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 123.68it/s]
# train_batch (Avg. Loss 0.814, Accuracy 79.5): 100%|██████████| 40/40 [00:00<00:00, 84.88it/s]
# test_batch (Avg. Loss 2.279, Accuracy 24.6): 100%|██████████| 40/40 [00:00<00:00, 107.85it/s]
# train_batch (Avg. Loss 0.779, Accuracy 79.0): 100%|██████████| 40/40 [00:00<00:00, 90.14it/s]
# test_batch (Avg. Loss 2.269, Accuracy 25.0): 100%|██████████| 40/40 [00:00<00:00, 116.71it/s]
# train_batch (Avg. Loss 0.720, Accuracy 81.5): 100%|██████████| 40/40 [00:00<00:00, 78.07it/s]
# test_batch (Avg. Loss 2.296, Accuracy 24.8): 100%|██████████| 40/40 [00:00<00:00, 126.71it/s]
# train_batch (Avg. Loss 0.753, Accuracy 80.2): 100%|██████████| 40/40 [00:00<00:00, 77.97it/s]
# test_batch (Avg. Loss 2.293, Accuracy 24.9): 100%|██████████| 40/40 [00:00<00:00, 148.77it/s]
# train_batch (Avg. Loss 0.722, Accuracy 81.0): 100%|██████████| 40/40 [00:00<00:00, 74.75it/s]
# test_batch (Avg. Loss 2.290, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 150.85it/s]
# --- EPOCH 25/30 ---
# train_batch (Avg. Loss 0.676, Accuracy 83.0): 100%|██████████| 40/40 [00:00<00:00, 100.97it/s]
# test_batch (Avg. Loss 2.328, Accuracy 24.6): 100%|██████████| 40/40 [00:00<00:00, 135.86it/s]
# train_batch (Avg. Loss 0.656, Accuracy 82.2): 100%|██████████| 40/40 [00:00<00:00, 88.76it/s]
# test_batch (Avg. Loss 2.324, Accuracy 25.4): 100%|██████████| 40/40 [00:00<00:00, 120.82it/s]
# train_batch (Avg. Loss 0.660, Accuracy 84.2): 100%|██████████| 40/40 [00:00<00:00, 85.72it/s]
# test_batch (Avg. Loss 2.303, Accuracy 25.6): 100%|██████████| 40/40 [00:00<00:00, 145.54it/s]
# train_batch (Avg. Loss 0.598, Accuracy 86.5): 100%|██████████| 40/40 [00:00<00:00, 88.64it/s]
# test_batch (Avg. Loss 2.319, Accuracy 25.5): 100%|██████████| 40/40 [00:00<00:00, 158.29it/s]
# train_batch (Avg. Loss 0.581, Accuracy 84.8): 100%|██████████| 40/40 [00:00<00:00, 85.64it/s]
# test_batch (Avg. Loss 2.340, Accuracy 25.0): 100%|██████████| 40/40 [00:00<00:00, 132.21it/s]
# --- EPOCH 30/30 ---
# train_batch (Avg. Loss 0.559, Accuracy 88.0): 100%|██████████| 40/40 [00:00<00:00, 97.33it/s]
# test_batch (Avg. Loss 2.359, Accuracy 25.9): 100%|██████████| 40/40 [00:00<00:00, 122.83it/s]

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw2/answers.py`.

# %%
from cs236605.answers import display_answer
import hw2.answers

# %% [markdown]
# ### Question 1
#
# Regarding the graphs you got for the three dropout configurations:
#
# 1. Explain the graphs of no-dropout vs dropout. Do they match what you expected to see?
#     - If yes, explain why and provide examples based on the graphs.
#     - If no, explain what you think the problem is and what should be modified to fix it.
#
# 2. Compare the low-dropout setting to the high-dropout setting and explain based on your graphs.

# %%
display_answer(hw2.answers.part2_q1)
# Out:
# **Your answer:**
#
# 1. Yes, the graphs match what we expected to see. the lower the dropout, the bigger the overfitting is. in the first graph we can observe that there's quite extensive overfitting when the dropout is zero (the model increase its accuracy on the training set - 90 precent - but not on the test set - 20 percent). the more we increase the dropout portion, we get less overfitting, until we get real underfitting with the highest dropout.
#
# 2. we can see from the graphs that the low-dropout model is as we say overfiiting, and the high-dropout model is underfitting since the acc on the train and the test sets is low. we can infer from that that he model was to general and diddn't succeded learning the data well.

# %% [markdown]
# ### Question 2
#
# When training a model with the cross-entropy loss function, is it possible for the test loss to **increase** for a few epochs while the test accuracy also **increases**?
#
# If it's possible explain how, if it's not explain why not.

# %%
display_answer(hw2.answers.part2_q2)
# Out:
# **Your answer:**
#
# Yes, it is possible for the accuracy to increase while the loss is also increasing for a few ephoc. since the accuracy is zero-one loss, which means that it only counts the number of succeses while the loss calculates a function of the distances from the correct answer. so if in the learnign process the model decreased the number of errors (in 0-1 terms) but "pushed" all the data points farther from the imaginary hyperplane, so that the remaining error's distance increases, the described phenomena will occur.
